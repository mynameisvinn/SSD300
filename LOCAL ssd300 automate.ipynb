# %% [markdown]
# # Preparing for Sagemaker
# ## Code
# ### Uploading local code
# There should be a single folder with code. the name of this folder will be passed as an argument for `source_dir`.
#
# ### Importing third party modules
# You can add a `requirements.txt` file for external packages, which would be installed by sagemaker as long as it is accompanied by a `setup.py`.
#
# ### Importing custom modules
# For internal modules, you need to explicitly pass the name of the module as dependencies.
#
# For example, if you want to access a module called `ssd300` in the scripts folder, you need to pass it to SageMaker as:
# ```python
# {dependencies=['scripts/ssd300']
# ```
#
# ## Data
# ### Local data
# For local data with the name `data_dir`, you need to specify it as:
# ```python
# inputs = {'training': f'file://{data_dir}'}
# ```
# ### Remote data
# For remote data, you to upload to s3 and then point Sagemaker to that bucket.
#
# ## Training Code
# ### Command line arguments
# All training scripts must be able to accept the following arguments:
# ```python
# p.add_argument('--model-dir', type=str, default=os.environ.get('SM_MODEL_DIR'))  # for tf
# p.add_argument('--model_dir', type=str, default=os.environ.get('SM_MODEL_DIR'))  # for pytorch
# p.add_argument('--data_dir', type=str, default = os.environ.get('SM_CHANNEL_TRAINING'))
# ```
# ### Accessing uploaded data
# `SM_CHANNEL_XX` is the location of your data. For example, if you passed inputs with:
# ```python
# inputs = {'training': training_data, 'test': test_data}
# ```
# then you can access that data through `os.environ.get('SM_CHANNEL_TRAINING')` and `os.environ.get('SM_CHANNEL_TEST')`.
#
# The default location for `SM_CHANNEL_XX` is `/opt/ml/input/data/`. That means `SM_CHANNEL_TRAINING` is the equivalent to `/opt/ml/input/data/training`, and that `SM_CHANNEL_TEST` is equivalent to `/opt/ml/input/data/test`.
#
# ### Writing artifacts
# Any writes must be saved at `SM_MODEL_DIR`.
# ```python
# p.add_argument('-o', '--output_path', default = os.environ.get('SM_MODEL_DIR'))
# ```
# The default location for `SM_MODEL_DIR` is `/opt/ml/model`.

# %%
import sagemaker
import os
from sagemaker.tensorflow import TensorFlow

sess = sagemaker.Session()
role = "SageMakerRole"

# %%
git_config = {'repo': 'https://github.com/mynameisvinn/SSD300', 
              'branch': 'master'}

# %%
tf_estimator = TensorFlow(entry_point='train_ssd300.py', 
                          role=role,
                          source_dir="scripts",
                          instance_count=1, 
                          instance_type='local',
                          framework_version='1.12.0', 
                          py_version='py3',
                          script_mode=True,
                          dependencies=['scripts/ssd300'],
                          hyperparameters={
                              'epochs': 2,
                              'batch_size': 1,
                              'data_def_dir': '/opt/ml/input/data/training/tooth_id_v1.3',
                              'reload_data_path': '/opt/ml/input/data/training/image_label_sample_data.npy',
                              'exp_name': 'myexperiment',
                              'model_type': 'tooth-id',
                              'steps_per_epoch': 1,
                          }
                         )

# %%
data_dir = os.path.join(os.getcwd(), 'for_vin')
f'file://{data_dir}'
# Out:
# 'file:///Users/mynameisvinn/Dropbox/Temp/ml_dental_ssd300/for_vin'

# %%
inputs = {'training': f'file://{data_dir}'}
tf_estimator.fit(inputs)
# Out:
# Building with native build. Learn about native build in Compose here: https://docs.docker.com/go/compose-native-build/
# Creating tj6lg3zzpl-algo-1-mi3m8 ...
# Creating tj6lg3zzpl-algo-1-mi3m8 ... done
# Attaching to tj6lg3zzpl-algo-1-mi3m8
# tj6lg3zzpl-algo-1-mi3m8 | 2021-02-15 19:41:51,014 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# tj6lg3zzpl-algo-1-mi3m8 | 2021-02-15 19:41:51,027 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# tj6lg3zzpl-algo-1-mi3m8 | 2021-02-15 19:41:51,707 sagemaker-containers INFO     Installing module with the following command:
# tj6lg3zzpl-algo-1-mi3m8 | /usr/bin/python -m pip install -U . -r requirements.txt
# tj6lg3zzpl-algo-1-mi3m8 | Processing /opt/ml/code
# tj6lg3zzpl-algo-1-mi3m8 | Collecting matplotlib==3.3.2 (from -r requirements.txt (line 1))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/cd/d6/8c4dfb23151d5a494c66ebbfdb5c8c433b44ec07fae52da5939fcda0943f/matplotlib-3.3.2-cp36-cp36m-manylinux1_x86_64.whl (11.6MB)
#     100% |████████████████████████████████| 11.6MB 3.0MB/s ta 0:00:011
# tj6lg3zzpl-algo-1-mi3m8 | Collecting neptune_client==0.4.121 (from -r requirements.txt (line 2))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/4e/1f/baec54dc9e882323d4022da082048026f7521d1084d47da3e1bd2a99f325/neptune-client-0.4.121.tar.gz (90kB)
#     100% |████████████████████████████████| 92kB 2.2MB/s ta 0:00:01
# tj6lg3zzpl-algo-1-mi3m8 | Collecting asposestorage==1.0.2 (from -r requirements.txt (line 3))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/24/1a/85a4191b86c7b1d5cf18e5c6a3d5c7699d2fcdd78230f8d7a642dfa56ad1/asposestorage-1.0.2.tar.gz
# tj6lg3zzpl-algo-1-mi3m8 | Collecting opencv-contrib-python-headless==3.4.8.29 (from -r requirements.txt (line 4))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/fa/89/6b6f159cfdde0ff6986d83687cf9fe14f963f57a271b888797763634748b/opencv_contrib_python_headless-3.4.8.29-cp36-cp36m-manylinux1_x86_64.whl (27.7MB)
#     100% |████████████████████████████████| 27.7MB 1.8MB/s ta 0:00:011
# tj6lg3zzpl-algo-1-mi3m8 | Collecting keras==2.1.6 (from -r requirements.txt (line 5))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/54/e8/eaff7a09349ae9bd40d3ebaf028b49f5e2392c771f294910f75bb608b241/Keras-2.1.6-py2.py3-none-any.whl (339kB)
#     100% |████████████████████████████████| 348kB 4.4MB/s ta 0:00:01
# tj6lg3zzpl-algo-1-mi3m8 | Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.3 (from matplotlib==3.3.2->-r requirements.txt (line 1))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/8a/bb/488841f56197b13700afd5658fc279a2025a39e22449b7cf29864669b15d/pyparsing-2.4.7-py2.py3-none-any.whl (67kB)
#     100% |████████████████████████████████| 71kB 7.2MB/s ta 0:00:01
# tj6lg3zzpl-algo-1-mi3m8 | Collecting certifi>=2020.06.20 (from matplotlib==3.3.2->-r requirements.txt (line 1))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/5e/a0/5f06e1e1d463903cf0c0eebeb751791119ed7a4b3737fdc9a77f1cdfb51f/certifi-2020.12.5-py2.py3-none-any.whl (147kB)
#     100% |████████████████████████████████| 153kB 4.3MB/s ta 0:00:01
# tj6lg3zzpl-algo-1-mi3m8 | Collecting pillow>=6.2.0 (from matplotlib==3.3.2->-r requirements.txt (line 1))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/b6/c0/442d9d87e0da00bf856ef6dd4916f84a2d710b5f1a367d42d7f3c4e99a6c/Pillow-8.1.0-cp36-cp36m-manylinux1_x86_64.whl (2.2MB)
#     100% |████████████████████████████████| 2.2MB 2.5MB/s ta 0:00:011
# tj6lg3zzpl-algo-1-mi3m8 | Collecting kiwisolver>=1.0.1 (from matplotlib==3.3.2->-r requirements.txt (line 1))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/a7/1b/cbd8ae738719b5f41592a12057ef5442e2ed5f5cb5451f8fc7e9f8875a1a/kiwisolver-1.3.1-cp36-cp36m-manylinux1_x86_64.whl (1.1MB)
#     100% |████████████████████████████████| 1.1MB 10.8MB/s ta 0:00:01
# tj6lg3zzpl-algo-1-mi3m8 | Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib==3.3.2->-r requirements.txt (line 1)) (2.8.0)
# tj6lg3zzpl-algo-1-mi3m8 | Collecting cycler>=0.10 (from matplotlib==3.3.2->-r requirements.txt (line 1))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/f7/d2/e07d3ebb2bd7af696440ce7e754c59dd546ffe1bbe732c8ab68b9c834e61/cycler-0.10.0-py2.py3-none-any.whl
# tj6lg3zzpl-algo-1-mi3m8 | Requirement already satisfied, skipping upgrade: numpy>=1.15 in /usr/local/lib/python3.6/dist-packages (from matplotlib==3.3.2->-r requirements.txt (line 1)) (1.16.3)
# tj6lg3zzpl-algo-1-mi3m8 | Collecting bravado (from neptune_client==0.4.121->-r requirements.txt (line 2))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/6d/3d/f8772d9295c03e08a9ab4afc1ccd195efe6cb4d1af3135b7f74eb8beb0d6/bravado-11.0.2-py2.py3-none-any.whl
# tj6lg3zzpl-algo-1-mi3m8 | Requirement already satisfied, skipping upgrade: click>=7.0 in /usr/local/lib/python3.6/dist-packages (from neptune_client==0.4.121->-r requirements.txt (line 2)) (7.0)
# tj6lg3zzpl-algo-1-mi3m8 | Collecting future>=0.17.1 (from neptune_client==0.4.121->-r requirements.txt (line 2))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/45/0b/38b06fd9b92dc2b68d58b75f900e97884c45bedd2ff83203d933cf5851c9/future-0.18.2.tar.gz (829kB)
#     100% |████████████████████████████████| 829kB 4.8MB/s ta 0:00:011
# tj6lg3zzpl-algo-1-mi3m8 | Collecting py3nvml (from neptune_client==0.4.121->-r requirements.txt (line 2))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/53/b3/cb30dd8cc1198ae3fdb5a320ca7986d7ca76e23d16415067eafebff8685f/py3nvml-0.2.6-py3-none-any.whl (55kB)
#     100% |████████████████████████████████| 61kB 5.4MB/s ta 0:00:01
# tj6lg3zzpl-algo-1-mi3m8 | Collecting oauthlib>=2.1.0 (from neptune_client==0.4.121->-r requirements.txt (line 2))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/05/57/ce2e7a8fa7c0afb54a0581b14a65b56e62b5759dbc98e80627142b8a3704/oauthlib-3.1.0-py2.py3-none-any.whl (147kB)
#     100% |████████████████████████████████| 153kB 4.4MB/s ta 0:00:01
# tj6lg3zzpl-algo-1-mi3m8 | Requirement already satisfied, skipping upgrade: pandas in /usr/local/lib/python3.6/dist-packages (from neptune_client==0.4.121->-r requirements.txt (line 2)) (0.24.2)
# tj6lg3zzpl-algo-1-mi3m8 | Collecting PyJWT (from neptune_client==0.4.121->-r requirements.txt (line 2))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/b4/9b/8850f99027ed029af6828199cc87179eaccbbf1f9e6e373e7f0177d32dad/PyJWT-2.0.1-py3-none-any.whl
# tj6lg3zzpl-algo-1-mi3m8 | Collecting requests>=2.20.0 (from neptune_client==0.4.121->-r requirements.txt (line 2))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/29/c1/24814557f1d22c56d50280771a17307e6bf87b70727d975fd6b2ce6b014a/requests-2.25.1-py2.py3-none-any.whl (61kB)
#     100% |████████████████████████████████| 61kB 3.7MB/s ta 0:00:01
# tj6lg3zzpl-algo-1-mi3m8 | Collecting requests-oauthlib>=1.0.0 (from neptune_client==0.4.121->-r requirements.txt (line 2))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/a3/12/b92740d845ab62ea4edf04d2f4164d82532b5a0b03836d4d4e71c6f3d379/requests_oauthlib-1.3.0-py2.py3-none-any.whl
# tj6lg3zzpl-algo-1-mi3m8 | Requirement already satisfied, skipping upgrade: six>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from neptune_client==0.4.121->-r requirements.txt (line 2)) (1.12.0)
# tj6lg3zzpl-algo-1-mi3m8 | Collecting websocket-client>=0.35.0 (from neptune_client==0.4.121->-r requirements.txt (line 2))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/4c/5f/f61b420143ed1c8dc69f9eaec5ff1ac36109d52c80de49d66e0c36c3dfdf/websocket_client-0.57.0-py2.py3-none-any.whl (200kB)
#     100% |████████████████████████████████| 204kB 3.4MB/s ta 0:00:01
# tj6lg3zzpl-algo-1-mi3m8 | Collecting GitPython>=2.0.8 (from neptune_client==0.4.121->-r requirements.txt (line 2))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/fb/67/47a04d8a9d7f94645676fe683f1ee3fe9be01fe407686c180768a92abaac/GitPython-3.1.13-py3-none-any.whl (159kB)
#     100% |████████████████████████████████| 163kB 8.3MB/s ta 0:00:01
# tj6lg3zzpl-algo-1-mi3m8 | Collecting packaging (from neptune_client==0.4.121->-r requirements.txt (line 2))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/3e/89/7ea760b4daa42653ece2380531c90f64788d979110a2ab51049d92f408af/packaging-20.9-py2.py3-none-any.whl (40kB)
#     100% |████████████████████████████████| 40kB 2.4MB/s ta 0:00:01
# tj6lg3zzpl-algo-1-mi3m8 | Requirement already satisfied, skipping upgrade: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras==2.1.6->-r requirements.txt (line 5)) (1.3.0)
# tj6lg3zzpl-algo-1-mi3m8 | Requirement already satisfied, skipping upgrade: h5py in /usr/local/lib/python3.6/dist-packages (from keras==2.1.6->-r requirements.txt (line 5)) (2.9.0)
# tj6lg3zzpl-algo-1-mi3m8 | Requirement already satisfied, skipping upgrade: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.1.6->-r requirements.txt (line 5)) (5.1)
# tj6lg3zzpl-algo-1-mi3m8 | Collecting msgpack (from bravado->neptune_client==0.4.121->-r requirements.txt (line 2))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/0c/0d/b1d9d32d03ce38ba5e2a37fbae850afd4530a14cc441e8335f1865a03705/msgpack-1.0.2-cp36-cp36m-manylinux1_x86_64.whl (272kB)
#     100% |████████████████████████████████| 276kB 11.5MB/s ta 0:00:01
# tj6lg3zzpl-algo-1-mi3m8 | Collecting typing-extensions (from bravado->neptune_client==0.4.121->-r requirements.txt (line 2))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/60/7a/e881b5abb54db0e6e671ab088d079c57ce54e8a01a3ca443f561ccadb37e/typing_extensions-3.7.4.3-py3-none-any.whl
# tj6lg3zzpl-algo-1-mi3m8 | Collecting bravado-core>=5.16.1 (from bravado->neptune_client==0.4.121->-r requirements.txt (line 2))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/76/11/18e9d28a156c33f2d5f15a5e155dc7130250acb0a569255a2b6b307b596d/bravado_core-5.17.0-py2.py3-none-any.whl (67kB)
#     100% |████████████████████████████████| 71kB 6.9MB/s ta 0:00:01
# tj6lg3zzpl-algo-1-mi3m8 | Collecting simplejson (from bravado->neptune_client==0.4.121->-r requirements.txt (line 2))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/c4/76/6c18cafdd84cb87ea737ec52965dc1d8730f0d8e8d019c1efaf0b58abb32/simplejson-3.17.2-cp36-cp36m-manylinux1_x86_64.whl (127kB)
#     100% |████████████████████████████████| 133kB 8.7MB/s eta 0:00:01
# tj6lg3zzpl-algo-1-mi3m8 | Collecting monotonic (from bravado->neptune_client==0.4.121->-r requirements.txt (line 2))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/ac/aa/063eca6a416f397bd99552c534c6d11d57f58f2e94c14780f3bbf818c4cf/monotonic-1.5-py2.py3-none-any.whl
# tj6lg3zzpl-algo-1-mi3m8 | Collecting xmltodict (from py3nvml->neptune_client==0.4.121->-r requirements.txt (line 2))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/28/fd/30d5c1d3ac29ce229f6bdc40bbc20b28f716e8b363140c26eff19122d8a5/xmltodict-0.12.0-py2.py3-none-any.whl
# tj6lg3zzpl-algo-1-mi3m8 | Requirement already satisfied, skipping upgrade: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas->neptune_client==0.4.121->-r requirements.txt (line 2)) (2019.1)
# tj6lg3zzpl-algo-1-mi3m8 | Requirement already satisfied, skipping upgrade: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20.0->neptune_client==0.4.121->-r requirements.txt (line 2)) (1.24.3)
# tj6lg3zzpl-algo-1-mi3m8 | Collecting chardet<5,>=3.0.2 (from requests>=2.20.0->neptune_client==0.4.121->-r requirements.txt (line 2))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/19/c7/fa589626997dd07bd87d9269342ccb74b1720384a4d739a1872bd84fbe68/chardet-4.0.0-py2.py3-none-any.whl (178kB)
#     100% |████████████████████████████████| 184kB 8.7MB/s ta 0:00:011
# tj6lg3zzpl-algo-1-mi3m8 | Collecting idna<3,>=2.5 (from requests>=2.20.0->neptune_client==0.4.121->-r requirements.txt (line 2))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/a2/38/928ddce2273eaa564f6f50de919327bf3a00f091b5baba8dfa9460f3a8a8/idna-2.10-py2.py3-none-any.whl (58kB)
#     100% |████████████████████████████████| 61kB 6.7MB/s ta 0:00:01
# tj6lg3zzpl-algo-1-mi3m8 | Collecting gitdb<5,>=4.0.1 (from GitPython>=2.0.8->neptune_client==0.4.121->-r requirements.txt (line 2))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/48/11/d1800bca0a3bae820b84b7d813ad1eff15a48a64caea9c823fc8c1b119e8/gitdb-4.0.5-py3-none-any.whl (63kB)
#     100% |████████████████████████████████| 71kB 1.6MB/s ta 0:00:01
# tj6lg3zzpl-algo-1-mi3m8 | Collecting swagger-spec-validator>=2.0.1 (from bravado-core>=5.16.1->bravado->neptune_client==0.4.121->-r requirements.txt (line 2))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/09/de/e78cefbf5838b434b63a789264b79821cb2267f1498fbed23ef8590133e4/swagger_spec_validator-2.7.3-py2.py3-none-any.whl
# tj6lg3zzpl-algo-1-mi3m8 | Collecting jsonschema[format]>=2.5.1 (from bravado-core>=5.16.1->bravado->neptune_client==0.4.121->-r requirements.txt (line 2))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/c5/8f/51e89ce52a085483359217bc72cdbf6e75ee595d5b1d4b5ade40c7e018b8/jsonschema-3.2.0-py2.py3-none-any.whl (56kB)
#     100% |████████████████████████████████| 61kB 2.9MB/s ta 0:00:01
# tj6lg3zzpl-algo-1-mi3m8 | Collecting jsonref (from bravado-core>=5.16.1->bravado->neptune_client==0.4.121->-r requirements.txt (line 2))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/07/92/f8e4ac824b14af77e613984e480fa818397c72d4141fc466decb26752749/jsonref-0.2-py3-none-any.whl
# tj6lg3zzpl-algo-1-mi3m8 | Collecting smmap<4,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython>=2.0.8->neptune_client==0.4.121->-r requirements.txt (line 2))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/d5/1e/6130925131f639b2acde0f7f18b73e33ce082ff2d90783c436b52040af5a/smmap-3.0.5-py2.py3-none-any.whl
# tj6lg3zzpl-algo-1-mi3m8 | Collecting attrs>=17.4.0 (from jsonschema[format]>=2.5.1->bravado-core>=5.16.1->bravado->neptune_client==0.4.121->-r requirements.txt (line 2))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/c3/aa/cb45262569fcc047bf070b5de61813724d6726db83259222cd7b4c79821a/attrs-20.3.0-py2.py3-none-any.whl (49kB)
#     100% |████████████████████████████████| 51kB 10.6MB/s ta 0:00:01
# tj6lg3zzpl-algo-1-mi3m8 | Collecting importlib-metadata; python_version < "3.8" (from jsonschema[format]>=2.5.1->bravado-core>=5.16.1->bravado->neptune_client==0.4.121->-r requirements.txt (line 2))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/f3/ed/da40116a204abb5c4dd1d929346d33e0d29cedb2cedd18ea98f0385dcd92/importlib_metadata-3.4.0-py3-none-any.whl
# tj6lg3zzpl-algo-1-mi3m8 | Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from jsonschema[format]>=2.5.1->bravado-core>=5.16.1->bravado->neptune_client==0.4.121->-r requirements.txt (line 2)) (41.0.1)
# tj6lg3zzpl-algo-1-mi3m8 | Collecting pyrsistent>=0.14.0 (from jsonschema[format]>=2.5.1->bravado-core>=5.16.1->bravado->neptune_client==0.4.121->-r requirements.txt (line 2))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/4d/70/fd441df751ba8b620e03fd2d2d9ca902103119616f0f6cc42e6405035062/pyrsistent-0.17.3.tar.gz (106kB)
#     100% |████████████████████████████████| 112kB 4.2MB/s ta 0:00:01
# tj6lg3zzpl-algo-1-mi3m8 | Collecting webcolors; extra == "format" (from jsonschema[format]>=2.5.1->bravado-core>=5.16.1->bravado->neptune_client==0.4.121->-r requirements.txt (line 2))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/12/05/3350559de9714b202e443a9e6312937341bd5f79f4e4f625744295e7dd17/webcolors-1.11.1-py3-none-any.whl
# tj6lg3zzpl-algo-1-mi3m8 | Collecting strict-rfc3339; extra == "format" (from jsonschema[format]>=2.5.1->bravado-core>=5.16.1->bravado->neptune_client==0.4.121->-r requirements.txt (line 2))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/56/e4/879ef1dbd6ddea1c77c0078cd59b503368b0456bcca7d063a870ca2119d3/strict-rfc3339-0.7.tar.gz
# tj6lg3zzpl-algo-1-mi3m8 | Collecting jsonpointer>1.13; extra == "format" (from jsonschema[format]>=2.5.1->bravado-core>=5.16.1->bravado->neptune_client==0.4.121->-r requirements.txt (line 2))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/18/b0/a80d29577c08eea401659254dfaed87f1af45272899e1812d7e01b679bc5/jsonpointer-2.0-py2.py3-none-any.whl
# tj6lg3zzpl-algo-1-mi3m8 | Collecting rfc3987; extra == "format" (from jsonschema[format]>=2.5.1->bravado-core>=5.16.1->bravado->neptune_client==0.4.121->-r requirements.txt (line 2))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/65/d4/f7407c3d15d5ac779c3dd34fbbc6ea2090f77bd7dd12f207ccf881551208/rfc3987-1.3.8-py2.py3-none-any.whl
# tj6lg3zzpl-algo-1-mi3m8 | Collecting zipp>=0.5 (from importlib-metadata; python_version < "3.8"->jsonschema[format]>=2.5.1->bravado-core>=5.16.1->bravado->neptune_client==0.4.121->-r requirements.txt (line 2))
# tj6lg3zzpl-algo-1-mi3m8 |   Downloading https://files.pythonhosted.org/packages/41/ad/6a4f1a124b325618a7fb758b885b68ff7b058eec47d9220a12ab38d90b1f/zipp-3.4.0-py3-none-any.whl
# tj6lg3zzpl-algo-1-mi3m8 | Building wheels for collected packages: neptune-client, asposestorage, ml-dental-ssd300, future, pyrsistent, strict-rfc3339
# tj6lg3zzpl-algo-1-mi3m8 |   Running setup.py bdist_wheel for neptune-client ... done
# tj6lg3zzpl-algo-1-mi3m8 |   Stored in directory: /root/.cache/pip/wheels/e8/16/8a/fe58ef0509b6c1ba73cc0794fe858a6988ff7e69399608a19c
# tj6lg3zzpl-algo-1-mi3m8 |   Running setup.py bdist_wheel for asposestorage ... done
# tj6lg3zzpl-algo-1-mi3m8 |   Stored in directory: /root/.cache/pip/wheels/db/d5/5d/c7994216a751c912db8f62e78a41ce4962054fc6ad5abf78d2
# tj6lg3zzpl-algo-1-mi3m8 |   Running setup.py bdist_wheel for ml-dental-ssd300 ... done
# tj6lg3zzpl-algo-1-mi3m8 |   Stored in directory: /tmp/pip-ephem-wheel-cache-j01w0puk/wheels/35/24/16/37574d11bf9bde50616c67372a334f94fa8356bc7164af8ca3
# tj6lg3zzpl-algo-1-mi3m8 |   Running setup.py bdist_wheel for future ... done
# tj6lg3zzpl-algo-1-mi3m8 |   Stored in directory: /root/.cache/pip/wheels/8b/99/a0/81daf51dcd359a9377b110a8a886b3895921802d2fc1b2397e
# tj6lg3zzpl-algo-1-mi3m8 |   Running setup.py bdist_wheel for pyrsistent ... done
# tj6lg3zzpl-algo-1-mi3m8 |   Stored in directory: /root/.cache/pip/wheels/f0/b8/de/b593ad311be4eb458499d100db081e453576032272398b7ddc
# tj6lg3zzpl-algo-1-mi3m8 |   Running setup.py bdist_wheel for strict-rfc3339 ... done
# tj6lg3zzpl-algo-1-mi3m8 |   Stored in directory: /root/.cache/pip/wheels/bb/af/c9/b6e9fb5f9b2470e4ed2a7241c9ab3a8cdd3bc8555ae02ca2e6
# tj6lg3zzpl-algo-1-mi3m8 | Successfully built neptune-client asposestorage ml-dental-ssd300 future pyrsistent strict-rfc3339
# tj6lg3zzpl-algo-1-mi3m8 | Installing collected packages: pyparsing, certifi, pillow, kiwisolver, cycler, matplotlib, msgpack, typing-extensions, attrs, zipp, importlib-metadata, pyrsistent, idna, webcolors, strict-rfc3339, jsonpointer, rfc3987, jsonschema, swagger-spec-validator, simplejson, jsonref, bravado-core, chardet, requests, monotonic, bravado, future, xmltodict, py3nvml, oauthlib, PyJWT, requests-oauthlib, websocket-client, smmap, gitdb, GitPython, packaging, neptune-client, asposestorage, opencv-contrib-python-headless, keras, ml-dental-ssd300
# tj6lg3zzpl-algo-1-mi3m8 |   Found existing installation: Pillow 6.0.0
# tj6lg3zzpl-algo-1-mi3m8 |     Uninstalling Pillow-6.0.0:
# tj6lg3zzpl-algo-1-mi3m8 |       Successfully uninstalled Pillow-6.0.0
# tj6lg3zzpl-algo-1-mi3m8 |   Found existing installation: Keras 2.2.4
# tj6lg3zzpl-algo-1-mi3m8 |     Uninstalling Keras-2.2.4:
# tj6lg3zzpl-algo-1-mi3m8 |       Successfully uninstalled Keras-2.2.4
# tj6lg3zzpl-algo-1-mi3m8 | Successfully installed GitPython-3.1.13 PyJWT-2.0.1 asposestorage-1.0.2 attrs-20.3.0 bravado-11.0.2 bravado-core-5.17.0 certifi-2020.12.5 chardet-4.0.0 cycler-0.10.0 future-0.18.2 gitdb-4.0.5 idna-2.10 importlib-metadata-3.4.0 jsonpointer-2.0 jsonref-0.2 jsonschema-3.2.0 keras-2.1.6 kiwisolver-1.3.1 matplotlib-3.3.2 ml-dental-ssd300-1.0.0 monotonic-1.5 msgpack-1.0.2 neptune-client-0.4.121 oauthlib-3.1.0 opencv-contrib-python-headless-3.4.8.29 packaging-20.9 pillow-8.1.0 py3nvml-0.2.6 pyparsing-2.4.7 pyrsistent-0.17.3 requests-2.25.1 requests-oauthlib-1.3.0 rfc3987-1.3.8 simplejson-3.17.2 smmap-3.0.5 strict-rfc3339-0.7 swagger-spec-validator-2.7.3 typing-extensions-3.7.4.3 webcolors-1.11.1 websocket-client-0.57.0 xmltodict-0.12.0 zipp-3.4.0
# tj6lg3zzpl-algo-1-mi3m8 | You are using pip version 18.1, however version 21.0.1 is available.
# tj6lg3zzpl-algo-1-mi3m8 | You should consider upgrading via the 'pip install --upgrade pip' command.
# tj6lg3zzpl-algo-1-mi3m8 | 2021-02-15 19:42:20,233 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# tj6lg3zzpl-algo-1-mi3m8 | 2021-02-15 19:42:20,257 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# tj6lg3zzpl-algo-1-mi3m8 | 2021-02-15 19:42:20,272 sagemaker-containers INFO     Invoking user script
# tj6lg3zzpl-algo-1-mi3m8 |
# tj6lg3zzpl-algo-1-mi3m8 | Training Env:
# tj6lg3zzpl-algo-1-mi3m8 |
# tj6lg3zzpl-algo-1-mi3m8 | {
# tj6lg3zzpl-algo-1-mi3m8 |     "additional_framework_parameters": {},
# tj6lg3zzpl-algo-1-mi3m8 |     "channel_input_dirs": {
# tj6lg3zzpl-algo-1-mi3m8 |         "training": "/opt/ml/input/data/training"
# tj6lg3zzpl-algo-1-mi3m8 |     },
# tj6lg3zzpl-algo-1-mi3m8 |     "current_host": "algo-1-mi3m8",
# tj6lg3zzpl-algo-1-mi3m8 |     "framework_module": "sagemaker_tensorflow_container.training:main",
# tj6lg3zzpl-algo-1-mi3m8 |     "hosts": [
# tj6lg3zzpl-algo-1-mi3m8 |         "algo-1-mi3m8"
# tj6lg3zzpl-algo-1-mi3m8 |     ],
# tj6lg3zzpl-algo-1-mi3m8 |     "hyperparameters": {
# tj6lg3zzpl-algo-1-mi3m8 |         "epochs": 2,
# tj6lg3zzpl-algo-1-mi3m8 |         "batch_size": 1,
# tj6lg3zzpl-algo-1-mi3m8 |         "data_def_dir": "/opt/ml/input/data/training/tooth_id_v1.3",
# tj6lg3zzpl-algo-1-mi3m8 |         "reload_data_path": "/opt/ml/input/data/training/image_label_sample_data.npy",
# tj6lg3zzpl-algo-1-mi3m8 |         "exp_name": "myexperiment",
# tj6lg3zzpl-algo-1-mi3m8 |         "model_type": "tooth-id",
# tj6lg3zzpl-algo-1-mi3m8 |         "steps_per_epoch": 1,
# tj6lg3zzpl-algo-1-mi3m8 |         "model_dir": "s3://sagemaker-us-east-1-196099849067/sagemaker-tensorflow-scriptmode-2021-02-15-19-41-44-559/model"
# tj6lg3zzpl-algo-1-mi3m8 |     },
# tj6lg3zzpl-algo-1-mi3m8 |     "input_config_dir": "/opt/ml/input/config",
# tj6lg3zzpl-algo-1-mi3m8 |     "input_data_config": {
# tj6lg3zzpl-algo-1-mi3m8 |         "training": {
# tj6lg3zzpl-algo-1-mi3m8 |             "TrainingInputMode": "File"
# tj6lg3zzpl-algo-1-mi3m8 |         }
# tj6lg3zzpl-algo-1-mi3m8 |     },
# tj6lg3zzpl-algo-1-mi3m8 |     "input_dir": "/opt/ml/input",
# tj6lg3zzpl-algo-1-mi3m8 |     "is_master": true,
# tj6lg3zzpl-algo-1-mi3m8 |     "job_name": "sagemaker-tensorflow-scriptmode-2021-02-15-19-41-44-559",
# tj6lg3zzpl-algo-1-mi3m8 |     "log_level": 20,
# tj6lg3zzpl-algo-1-mi3m8 |     "master_hostname": "algo-1-mi3m8",
# tj6lg3zzpl-algo-1-mi3m8 |     "model_dir": "/opt/ml/model",
# tj6lg3zzpl-algo-1-mi3m8 |     "module_dir": "s3://sagemaker-us-east-1-196099849067/sagemaker-tensorflow-scriptmode-2021-02-15-19-41-44-559/source/sourcedir.tar.gz",
# tj6lg3zzpl-algo-1-mi3m8 |     "module_name": "train_ssd300",
# tj6lg3zzpl-algo-1-mi3m8 |     "network_interface_name": "eth0",
# tj6lg3zzpl-algo-1-mi3m8 |     "num_cpus": 4,
# tj6lg3zzpl-algo-1-mi3m8 |     "num_gpus": 0,
# tj6lg3zzpl-algo-1-mi3m8 |     "output_data_dir": "/opt/ml/output/data",
# tj6lg3zzpl-algo-1-mi3m8 |     "output_dir": "/opt/ml/output",
# tj6lg3zzpl-algo-1-mi3m8 |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# tj6lg3zzpl-algo-1-mi3m8 |     "resource_config": {
# tj6lg3zzpl-algo-1-mi3m8 |         "current_host": "algo-1-mi3m8",
# tj6lg3zzpl-algo-1-mi3m8 |         "hosts": [
# tj6lg3zzpl-algo-1-mi3m8 |             "algo-1-mi3m8"
# tj6lg3zzpl-algo-1-mi3m8 |         ]
# tj6lg3zzpl-algo-1-mi3m8 |     },
# tj6lg3zzpl-algo-1-mi3m8 |     "user_entry_point": "train_ssd300.py"
# tj6lg3zzpl-algo-1-mi3m8 | }
# tj6lg3zzpl-algo-1-mi3m8 |
# tj6lg3zzpl-algo-1-mi3m8 | Environment variables:
# tj6lg3zzpl-algo-1-mi3m8 |
# tj6lg3zzpl-algo-1-mi3m8 | SM_HOSTS=["algo-1-mi3m8"]
# tj6lg3zzpl-algo-1-mi3m8 | SM_NETWORK_INTERFACE_NAME=eth0
# tj6lg3zzpl-algo-1-mi3m8 | SM_HPS={"batch_size":1,"data_def_dir":"/opt/ml/input/data/training/tooth_id_v1.3","epochs":2,"exp_name":"myexperiment","model_dir":"s3://sagemaker-us-east-1-196099849067/sagemaker-tensorflow-scriptmode-2021-02-15-19-41-44-559/model","model_type":"tooth-id","reload_data_path":"/opt/ml/input/data/training/image_label_sample_data.npy","steps_per_epoch":1}
# tj6lg3zzpl-algo-1-mi3m8 | SM_USER_ENTRY_POINT=train_ssd300.py
# tj6lg3zzpl-algo-1-mi3m8 | SM_FRAMEWORK_PARAMS={}
# tj6lg3zzpl-algo-1-mi3m8 | SM_RESOURCE_CONFIG={"current_host":"algo-1-mi3m8","hosts":["algo-1-mi3m8"]}
# tj6lg3zzpl-algo-1-mi3m8 | SM_INPUT_DATA_CONFIG={"training":{"TrainingInputMode":"File"}}
# tj6lg3zzpl-algo-1-mi3m8 | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# tj6lg3zzpl-algo-1-mi3m8 | SM_CHANNELS=["training"]
# tj6lg3zzpl-algo-1-mi3m8 | SM_CURRENT_HOST=algo-1-mi3m8
# tj6lg3zzpl-algo-1-mi3m8 | SM_MODULE_NAME=train_ssd300
# tj6lg3zzpl-algo-1-mi3m8 | SM_LOG_LEVEL=20
# tj6lg3zzpl-algo-1-mi3m8 | SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# tj6lg3zzpl-algo-1-mi3m8 | SM_INPUT_DIR=/opt/ml/input
# tj6lg3zzpl-algo-1-mi3m8 | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# tj6lg3zzpl-algo-1-mi3m8 | SM_OUTPUT_DIR=/opt/ml/output
# tj6lg3zzpl-algo-1-mi3m8 | SM_NUM_CPUS=4
# tj6lg3zzpl-algo-1-mi3m8 | SM_NUM_GPUS=0
# tj6lg3zzpl-algo-1-mi3m8 | SM_MODEL_DIR=/opt/ml/model
# tj6lg3zzpl-algo-1-mi3m8 | SM_MODULE_DIR=s3://sagemaker-us-east-1-196099849067/sagemaker-tensorflow-scriptmode-2021-02-15-19-41-44-559/source/sourcedir.tar.gz
# tj6lg3zzpl-algo-1-mi3m8 | SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1-mi3m8","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1-mi3m8"],"hyperparameters":{"batch_size":1,"data_def_dir":"/opt/ml/input/data/training/tooth_id_v1.3","epochs":2,"exp_name":"myexperiment","model_dir":"s3://sagemaker-us-east-1-196099849067/sagemaker-tensorflow-scriptmode-2021-02-15-19-41-44-559/model","model_type":"tooth-id","reload_data_path":"/opt/ml/input/data/training/image_label_sample_data.npy","steps_per_epoch":1},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"sagemaker-tensorflow-scriptmode-2021-02-15-19-41-44-559","log_level":20,"master_hostname":"algo-1-mi3m8","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-196099849067/sagemaker-tensorflow-scriptmode-2021-02-15-19-41-44-559/source/sourcedir.tar.gz","module_name":"train_ssd300","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-mi3m8","hosts":["algo-1-mi3m8"]},"user_entry_point":"train_ssd300.py"}
# tj6lg3zzpl-algo-1-mi3m8 | SM_USER_ARGS=["--batch_size","1","--data_def_dir","/opt/ml/input/data/training/tooth_id_v1.3","--epochs","2","--exp_name","myexperiment","--model_dir","s3://sagemaker-us-east-1-196099849067/sagemaker-tensorflow-scriptmode-2021-02-15-19-41-44-559/model","--model_type","tooth-id","--reload_data_path","/opt/ml/input/data/training/image_label_sample_data.npy","--steps_per_epoch","1"]
# tj6lg3zzpl-algo-1-mi3m8 | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# tj6lg3zzpl-algo-1-mi3m8 | SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# tj6lg3zzpl-algo-1-mi3m8 | SM_HP_EPOCHS=2
# tj6lg3zzpl-algo-1-mi3m8 | SM_HP_BATCH_SIZE=1
# tj6lg3zzpl-algo-1-mi3m8 | SM_HP_DATA_DEF_DIR=/opt/ml/input/data/training/tooth_id_v1.3
# tj6lg3zzpl-algo-1-mi3m8 | SM_HP_RELOAD_DATA_PATH=/opt/ml/input/data/training/image_label_sample_data.npy
# tj6lg3zzpl-algo-1-mi3m8 | SM_HP_EXP_NAME=myexperiment
# tj6lg3zzpl-algo-1-mi3m8 | SM_HP_MODEL_TYPE=tooth-id
# tj6lg3zzpl-algo-1-mi3m8 | SM_HP_STEPS_PER_EPOCH=1
# tj6lg3zzpl-algo-1-mi3m8 | SM_HP_MODEL_DIR=s3://sagemaker-us-east-1-196099849067/sagemaker-tensorflow-scriptmode-2021-02-15-19-41-44-559/model
# tj6lg3zzpl-algo-1-mi3m8 | PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
# tj6lg3zzpl-algo-1-mi3m8 |
# tj6lg3zzpl-algo-1-mi3m8 | Invoking script with the following command:
# tj6lg3zzpl-algo-1-mi3m8 |
# tj6lg3zzpl-algo-1-mi3m8 | /usr/bin/python -m train_ssd300 --batch_size 1 --data_def_dir /opt/ml/input/data/training/tooth_id_v1.3 --epochs 2 --exp_name myexperiment --model_dir s3://sagemaker-us-east-1-196099849067/sagemaker-tensorflow-scriptmode-2021-02-15-19-41-44-559/model --model_type tooth-id --reload_data_path /opt/ml/input/data/training/image_label_sample_data.npy --steps_per_epoch 1
# tj6lg3zzpl-algo-1-mi3m8 |
# tj6lg3zzpl-algo-1-mi3m8 |
# tj6lg3zzpl-algo-1-mi3m8 | Using TensorFlow backend.
# tj6lg3zzpl-algo-1-mi3m8 | 2021-02-15 19:42:22,574:INFO:__main__:Initializing training module...
# tj6lg3zzpl-algo-1-mi3m8 | 2021-02-15 19:42:22,574:INFO:ssd300.train_eval.trainer:Loading image and label data...
# tj6lg3zzpl-algo-1-mi3m8 | 2021-02-15 19:42:22,574:INFO:ssd300.train_eval.trainer:Pre-existing data available, reading data...
# tj6lg3zzpl-algo-1-mi3m8 | 2021-02-15 19:42:22,628:INFO:ssd300.train_eval.trainer:Load data complete
# tj6lg3zzpl-algo-1-mi3m8 | 2021-02-15 19:42:22,628:INFO:ssd300.train_eval.trainer:Loading ssd300 model...
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | Layer (type)                    Output Shape         Param #     Connected to
# tj6lg3zzpl-algo-1-mi3m8 | ==================================================================================================
# tj6lg3zzpl-algo-1-mi3m8 | input_1 (InputLayer)            (None, 300, 300, 3)  0
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | identity_layer (Lambda)         (None, 300, 300, 3)  0           input_1[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | input_mean_normalization (Lambd (None, 300, 300, 3)  0           identity_layer[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | input_channel_swap (Lambda)     (None, 300, 300, 3)  0           input_mean_normalization[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv1_1 (Conv2D)                (None, 300, 300, 64) 1792        input_channel_swap[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv1_2 (Conv2D)                (None, 300, 300, 64) 36928       conv1_1[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | pool1 (MaxPooling2D)            (None, 150, 150, 64) 0           conv1_2[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv2_1 (Conv2D)                (None, 150, 150, 128 73856       pool1[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv2_2 (Conv2D)                (None, 150, 150, 128 147584      conv2_1[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | pool2 (MaxPooling2D)            (None, 75, 75, 128)  0           conv2_2[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv3_1 (Conv2D)                (None, 75, 75, 256)  295168      pool2[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv3_2 (Conv2D)                (None, 75, 75, 256)  590080      conv3_1[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv3_3 (Conv2D)                (None, 75, 75, 256)  590080      conv3_2[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | pool3 (MaxPooling2D)            (None, 38, 38, 256)  0           conv3_3[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv4_1 (Conv2D)                (None, 38, 38, 512)  1180160     pool3[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv4_2 (Conv2D)                (None, 38, 38, 512)  2359808     conv4_1[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv4_3 (Conv2D)                (None, 38, 38, 512)  2359808     conv4_2[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | pool4 (MaxPooling2D)            (None, 19, 19, 512)  0           conv4_3[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv5_1 (Conv2D)                (None, 19, 19, 512)  2359808     pool4[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv5_2 (Conv2D)                (None, 19, 19, 512)  2359808     conv5_1[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv5_3 (Conv2D)                (None, 19, 19, 512)  2359808     conv5_2[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | pool5 (MaxPooling2D)            (None, 19, 19, 512)  0           conv5_3[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | fc6 (Conv2D)                    (None, 19, 19, 1024) 4719616     pool5[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | fc7 (Conv2D)                    (None, 19, 19, 1024) 1049600     fc6[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv6_1 (Conv2D)                (None, 19, 19, 256)  262400      fc7[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv6_padding (ZeroPadding2D)   (None, 21, 21, 256)  0           conv6_1[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv6_2 (Conv2D)                (None, 10, 10, 512)  1180160     conv6_padding[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv7_1 (Conv2D)                (None, 10, 10, 128)  65664       conv6_2[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv7_padding (ZeroPadding2D)   (None, 12, 12, 128)  0           conv7_1[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv7_2 (Conv2D)                (None, 5, 5, 256)    295168      conv7_padding[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv8_1 (Conv2D)                (None, 5, 5, 128)    32896       conv7_2[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv8_2 (Conv2D)                (None, 3, 3, 256)    295168      conv8_1[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv9_1 (Conv2D)                (None, 3, 3, 128)    32896       conv8_2[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv4_3_norm (L2Normalization)  (None, 38, 38, 512)  512         conv4_3[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv9_2 (Conv2D)                (None, 1, 1, 256)    295168      conv9_1[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv4_3_norm_mbox_conf (Conv2D) (None, 38, 38, 136)  626824      conv4_3_norm[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | fc7_mbox_conf (Conv2D)          (None, 19, 19, 204)  1880268     fc7[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv6_2_mbox_conf (Conv2D)      (None, 10, 10, 204)  940236      conv6_2[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv7_2_mbox_conf (Conv2D)      (None, 5, 5, 204)    470220      conv7_2[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv8_2_mbox_conf (Conv2D)      (None, 3, 3, 136)    313480      conv8_2[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv9_2_mbox_conf (Conv2D)      (None, 1, 1, 136)    313480      conv9_2[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv4_3_norm_mbox_loc (Conv2D)  (None, 38, 38, 16)   73744       conv4_3_norm[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | fc7_mbox_loc (Conv2D)           (None, 19, 19, 24)   221208      fc7[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv6_2_mbox_loc (Conv2D)       (None, 10, 10, 24)   110616      conv6_2[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv7_2_mbox_loc (Conv2D)       (None, 5, 5, 24)     55320       conv7_2[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv8_2_mbox_loc (Conv2D)       (None, 3, 3, 16)     36880       conv8_2[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv9_2_mbox_loc (Conv2D)       (None, 1, 1, 16)     36880       conv9_2[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv4_3_norm_mbox_conf_reshape  (None, 5776, 34)     0           conv4_3_norm_mbox_conf[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | fc7_mbox_conf_reshape (Reshape) (None, 2166, 34)     0           fc7_mbox_conf[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv6_2_mbox_conf_reshape (Resh (None, 600, 34)      0           conv6_2_mbox_conf[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv7_2_mbox_conf_reshape (Resh (None, 150, 34)      0           conv7_2_mbox_conf[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv8_2_mbox_conf_reshape (Resh (None, 36, 34)       0           conv8_2_mbox_conf[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv9_2_mbox_conf_reshape (Resh (None, 4, 34)        0           conv9_2_mbox_conf[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv4_3_norm_mbox_priorbox (Anc (None, 38, 38, 4, 8) 0           conv4_3_norm_mbox_loc[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | fc7_mbox_priorbox (AnchorBoxes) (None, 19, 19, 6, 8) 0           fc7_mbox_loc[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv6_2_mbox_priorbox (AnchorBo (None, 10, 10, 6, 8) 0           conv6_2_mbox_loc[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv7_2_mbox_priorbox (AnchorBo (None, 5, 5, 6, 8)   0           conv7_2_mbox_loc[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv8_2_mbox_priorbox (AnchorBo (None, 3, 3, 4, 8)   0           conv8_2_mbox_loc[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv9_2_mbox_priorbox (AnchorBo (None, 1, 1, 4, 8)   0           conv9_2_mbox_loc[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | mbox_conf (Concatenate)         (None, 8732, 34)     0           conv4_3_norm_mbox_conf_reshape[0]
# tj6lg3zzpl-algo-1-mi3m8 |                                                                  fc7_mbox_conf_reshape[0][0]
# tj6lg3zzpl-algo-1-mi3m8 |                                                                  conv6_2_mbox_conf_reshape[0][0]
# tj6lg3zzpl-algo-1-mi3m8 |                                                                  conv7_2_mbox_conf_reshape[0][0]
# tj6lg3zzpl-algo-1-mi3m8 |                                                                  conv8_2_mbox_conf_reshape[0][0]
# tj6lg3zzpl-algo-1-mi3m8 |                                                                  conv9_2_mbox_conf_reshape[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv4_3_norm_mbox_loc_reshape ( (None, 5776, 4)      0           conv4_3_norm_mbox_loc[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | fc7_mbox_loc_reshape (Reshape)  (None, 2166, 4)      0           fc7_mbox_loc[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv6_2_mbox_loc_reshape (Resha (None, 600, 4)       0           conv6_2_mbox_loc[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv7_2_mbox_loc_reshape (Resha (None, 150, 4)       0           conv7_2_mbox_loc[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv8_2_mbox_loc_reshape (Resha (None, 36, 4)        0           conv8_2_mbox_loc[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv9_2_mbox_loc_reshape (Resha (None, 4, 4)         0           conv9_2_mbox_loc[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv4_3_norm_mbox_priorbox_resh (None, 5776, 8)      0           conv4_3_norm_mbox_priorbox[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | fc7_mbox_priorbox_reshape (Resh (None, 2166, 8)      0           fc7_mbox_priorbox[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv6_2_mbox_priorbox_reshape ( (None, 600, 8)       0           conv6_2_mbox_priorbox[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv7_2_mbox_priorbox_reshape ( (None, 150, 8)       0           conv7_2_mbox_priorbox[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv8_2_mbox_priorbox_reshape ( (None, 36, 8)        0           conv8_2_mbox_priorbox[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | conv9_2_mbox_priorbox_reshape ( (None, 4, 8)         0           conv9_2_mbox_priorbox[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | mbox_conf_softmax (Activation)  (None, 8732, 34)     0           mbox_conf[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | mbox_loc (Concatenate)          (None, 8732, 4)      0           conv4_3_norm_mbox_loc_reshape[0][
# tj6lg3zzpl-algo-1-mi3m8 |                                                                  fc7_mbox_loc_reshape[0][0]
# tj6lg3zzpl-algo-1-mi3m8 |                                                                  conv6_2_mbox_loc_reshape[0][0]
# tj6lg3zzpl-algo-1-mi3m8 |                                                                  conv7_2_mbox_loc_reshape[0][0]
# tj6lg3zzpl-algo-1-mi3m8 |                                                                  conv8_2_mbox_loc_reshape[0][0]
# tj6lg3zzpl-algo-1-mi3m8 |                                                                  conv9_2_mbox_loc_reshape[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | mbox_priorbox (Concatenate)     (None, 8732, 8)      0           conv4_3_norm_mbox_priorbox_reshap
# tj6lg3zzpl-algo-1-mi3m8 |                                                                  fc7_mbox_priorbox_reshape[0][0]
# tj6lg3zzpl-algo-1-mi3m8 |                                                                  conv6_2_mbox_priorbox_reshape[0][
# tj6lg3zzpl-algo-1-mi3m8 |                                                                  conv7_2_mbox_priorbox_reshape[0][
# tj6lg3zzpl-algo-1-mi3m8 |                                                                  conv8_2_mbox_priorbox_reshape[0][
# tj6lg3zzpl-algo-1-mi3m8 |                                                                  conv9_2_mbox_priorbox_reshape[0][
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | predictions (Concatenate)       (None, 8732, 46)     0           mbox_conf_softmax[0][0]
# tj6lg3zzpl-algo-1-mi3m8 |                                                                  mbox_loc[0][0]
# tj6lg3zzpl-algo-1-mi3m8 |                                                                  mbox_priorbox[0][0]
# tj6lg3zzpl-algo-1-mi3m8 | ==================================================================================================
# tj6lg3zzpl-algo-1-mi3m8 | Total params: 28,023,092
# tj6lg3zzpl-algo-1-mi3m8 | Trainable params: 28,023,092
# tj6lg3zzpl-algo-1-mi3m8 | Non-trainable params: 0
# tj6lg3zzpl-algo-1-mi3m8 | __________________________________________________________________________________________________
# tj6lg3zzpl-algo-1-mi3m8 | 2021-02-15 19:42:23,541:INFO:ssd300.train_eval.trainer:None
# tj6lg3zzpl-algo-1-mi3m8 | Epoch 1/2
# 1/1 [==============================] - 12s 12s/step - loss: 149.1058 - val_loss: 457.8549
# tj6lg3zzpl-algo-1-mi3m8 |
# tj6lg3zzpl-algo-1-mi3m8 | Epoch 00001: val_loss improved from inf to 457.85492, saving model to /opt/ml/model/checkpoint_epoch-01_loss-149.1058_val_loss-457.8549.h5
# tj6lg3zzpl-algo-1-mi3m8 | Epoch 2/2
# 1/1 [==============================] - 3s 3s/step - loss: 1182.4841 - val_loss: 30.4966
# tj6lg3zzpl-algo-1-mi3m8 |
# tj6lg3zzpl-algo-1-mi3m8 | Epoch 00002: val_loss improved from 457.85492 to 30.49664, saving model to /opt/ml/model/checkpoint_epoch-02_loss-1182.4841_val_loss-30.4966.h5
# tj6lg3zzpl-algo-1-mi3m8 | savvvvvving
# tj6lg3zzpl-algo-1-mi3m8 | 2021-02-15 19:42:50,429:INFO:ssd300.train_eval.trainer:savvvvvving
# tj6lg3zzpl-algo-1-mi3m8 | Traceback (most recent call last):
# tj6lg3zzpl-algo-1-mi3m8 |   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
# tj6lg3zzpl-algo-1-mi3m8 |     "__main__", mod_spec)
# tj6lg3zzpl-algo-1-mi3m8 |   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
# tj6lg3zzpl-algo-1-mi3m8 |     exec(code, run_globals)
# tj6lg3zzpl-algo-1-mi3m8 |   File "/opt/ml/code/train_ssd300.py", line 136, in <module>
# tj6lg3zzpl-algo-1-mi3m8 |     train_module.train()
# tj6lg3zzpl-algo-1-mi3m8 |   File "/opt/ml/code/ssd300/train_eval/trainer.py", line 230, in train
# tj6lg3zzpl-algo-1-mi3m8 |     self.model.save(os.path.join(os.environ.get('MODEL_DIR'), 'm_example_model.h5'))  #!
# tj6lg3zzpl-algo-1-mi3m8 |   File "/usr/lib/python3.6/posixpath.py", line 80, in join
# tj6lg3zzpl-algo-1-mi3m8 |     a = os.fspath(a)
# tj6lg3zzpl-algo-1-mi3m8 | TypeError: expected str, bytes or os.PathLike object, not NoneType
# tj6lg3zzpl-algo-1-mi3m8 | 2021-02-15 19:42:54,968 sagemaker-containers ERROR    ExecuteUserScriptError:
# tj6lg3zzpl-algo-1-mi3m8 | Command "/usr/bin/python -m train_ssd300 --batch_size 1 --data_def_dir /opt/ml/input/data/training/tooth_id_v1.3 --epochs 2 --exp_name myexperiment --model_dir s3://sagemaker-us-east-1-196099849067/sagemaker-tensorflow-scriptmode-2021-02-15-19-41-44-559/model --model_type tooth-id --reload_data_path /opt/ml/input/data/training/image_label_sample_data.npy --steps_per_epoch 1"
# tj6lg3zzpl-algo-1-mi3m8 exited with code 1
# 1
# Aborting on container exit...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/sagemaker/local/image.py in train(self, input_data_config, output_data_config, hyperparameters, job_name)
#     236         try:
# --> 237             _stream_output(process)
#     238         except RuntimeError as e:
#
# ~/anaconda3/lib/python3.8/site-packages/sagemaker/local/image.py in _stream_output(process)
#     886     if exit_code != 0:
# --> 887         raise RuntimeError("Process exited with code: %s" % exit_code)
#     888
#
# RuntimeError: Process exited with code: 1
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-13-7085253b0e58> in <module>
#       1 inputs = {'training': f'file://{data_dir}'}
# ----> 2 tf_estimator.fit(inputs)
#
# ~/anaconda3/lib/python3.8/site-packages/sagemaker/estimator.py in fit(self, inputs, wait, logs, job_name, experiment_config)
#     656         self._prepare_for_training(job_name=job_name)
#     657
# --> 658         self.latest_training_job = _TrainingJob.start_new(self, inputs, experiment_config)
#     659         self.jobs.append(self.latest_training_job)
#     660         if wait:
#
# ~/anaconda3/lib/python3.8/site-packages/sagemaker/estimator.py in start_new(cls, estimator, inputs, experiment_config)
#    1419         """
#    1420         train_args = cls._get_train_args(estimator, inputs, experiment_config)
# -> 1421         estimator.sagemaker_session.train(**train_args)
#    1422
#    1423         return cls(estimator.sagemaker_session, estimator._current_job_name)
#
# ~/anaconda3/lib/python3.8/site-packages/sagemaker/session.py in train(self, input_mode, input_config, role, job_name, output_config, resource_config, vpc_config, hyperparameters, stop_condition, tags, metric_definitions, enable_network_isolation, image_uri, algorithm_arn, encrypt_inter_container_traffic, use_spot_instances, checkpoint_s3_uri, checkpoint_local_path, experiment_config, debugger_rule_configs, debugger_hook_config, tensorboard_output_config, enable_sagemaker_metrics, profiler_rule_configs, profiler_config)
#     560         LOGGER.info("Creating training-job with name: %s", job_name)
#     561         LOGGER.debug("train request: %s", json.dumps(train_request, indent=4))
# --> 562         self.sagemaker_client.create_training_job(**train_request)
#     563
#     564     def _get_train_request(  # noqa: C901
#
# ~/anaconda3/lib/python3.8/site-packages/sagemaker/local/local_session.py in create_training_job(self, TrainingJobName, AlgorithmSpecification, OutputDataConfig, ResourceConfig, InputDataConfig, **kwargs)
#     184         hyperparameters = kwargs["HyperParameters"] if "HyperParameters" in kwargs else {}
#     185         logger.info("Starting training job")
# --> 186         training_job.start(InputDataConfig, OutputDataConfig, hyperparameters, TrainingJobName)
#     187
#     188         LocalSagemakerClient._training_jobs[TrainingJobName] = training_job
#
# ~/anaconda3/lib/python3.8/site-packages/sagemaker/local/entities.py in start(self, input_data_config, output_data_config, hyperparameters, job_name)
#     218         self.state = self._TRAINING
#     219
# --> 220         self.model_artifacts = self.container.train(
#     221             input_data_config, output_data_config, hyperparameters, job_name
#     222         )
#
# ~/anaconda3/lib/python3.8/site-packages/sagemaker/local/image.py in train(self, input_data_config, output_data_config, hyperparameters, job_name)
#     240             # which contains the exit code and append the command line to it.
#     241             msg = "Failed to run: %s, %s" % (compose_command, str(e))
# --> 242             raise RuntimeError(msg)
#     243         finally:
#     244             artifacts = self.retrieve_artifacts(compose_data, output_data_config, job_name)
#
# RuntimeError: Failed to run: ['docker-compose', '-f', '/private/var/folders/xb/tv5r7gc92ql_wr439ljm2wcr0000gn/T/tmpme2h_lmg/docker-compose.yaml', 'up', '--build', '--abort-on-container-exit'], Process exited with code: 1
